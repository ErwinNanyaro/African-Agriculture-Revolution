# %% [markdown]
# # 🌍 AFRICAN AGRICULTURE REVOLUTION
# ## 🌽 Notebook 2: Arusha Multi-Crop Farmer Analysis
# ### Analyzing 138 multi-crop farmers in Arusha region
#
# **Key Metrics:**
# - 138 Arusha farmers
# - Climate adaptation focus
# - $3,000-$8,000 revenue potential

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

print("✅ Libraries imported successfully")
print("🌍 African Agriculture Revolution - Arusha Analysis")

# %%
# Load Arusha data
df = pd.read_csv("../data/raw/both_crops_farmers_arusha.csv")

print(f"📊 Dataset Shape: {df.shape}")
print(f"👨‍🌾 Farmers Analyzed: {len(df)}")
print(f"📋 Variables Measured: {df.shape[1]}")

# Show first few columns
print("\nFirst 5 columns:")
for i, col in enumerate(df.columns[:5]):
    print(f"  {i+1}. {col}")

# %% [markdown]
# ## 📊 Analysis Results
#
# ### Climate Adaptation Focus:
# Arusha dataset focuses on climate adaptation strategies:
# - Weather pattern adaptation
# - Drought-resistant crops
# - Training and extension services
# - Rainwater harvesting
#
# ### Revenue Opportunities:
# 1. **Climate Dashboard**: $3,000-$8,000
# 2. **Adaptation Analytics**: $500-$1,500/month
# 3. **Research Projects**: $8,000-$15,000
#
# **GitHub Repository:** https://github.com/ErwinNanyaro/African-Agriculture-Revolution
