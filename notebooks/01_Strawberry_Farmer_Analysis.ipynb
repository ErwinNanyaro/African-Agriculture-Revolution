# %% [markdown]
# # 🌍 AFRICAN AGRICULTURE REVOLUTION
# ## 🍓 Notebook 1: Morogoro Strawberry Farmer Analysis
# ### Analyzing 160 strawberry farmers in Morogoro region
#
# **Key Metrics:**
# - 160 strawberry farmers
# - 7 social capital indicators
# - $2,000-$5,000 revenue potential

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

print("✅ Libraries imported successfully")
print("🌍 African Agriculture Revolution - Strawberry Analysis")

# %%
# Load strawberry data from GitHub
df = pd.read_csv("https://raw.githubusercontent.com/ErwinNanyaro/African-Agriculture-Revolution/main/data/raw/strawberry_farmers_morogoro.csv")

print(f"📊 Dataset Shape: {df.shape}")
print(f"👨‍🌾 Farmers Analyzed: {len(df)}")
print(f"📋 Variables Measured: {df.shape[1]}")

# Show first few columns
print("\nFirst 5 columns:")
for i, col in enumerate(df.columns[:5]):
    print(f"  {i+1}. {col}")

# %% [markdown]
# ## 📊 Analysis Results
#
# ### Social Capital Indicators Found:
# Based on the dataset analysis, we identified multiple social capital indicators including:
# - Trust networks
# - Sharing practices
# - Group participation
# - Cooperative memberships
#
# ### Revenue Opportunities:
# 1. **NGO Dashboard**: $2,000-$5,000
# 2. **Predictive Analytics**: $300-$1,000/month
# 3. **Consulting**: $5,000-$20,000/project
#
# **GitHub Repository:** https://github.com/ErwinNanyaro/African-Agriculture-Revolution
